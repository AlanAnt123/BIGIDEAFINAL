# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt


# Load dataset
df = pd.read_csv('e03a89dd-134a-4ee8-a2bd-62c40aeebc6f-2.csv')


#  This part defines the neighborhood column
neighborhood_col = 'INCIDENTNEIGHBORHOOD'


# This part of the code cleans up missing or blank neighborhood names
df[neighborhood_col] = df[neighborhood_col].fillna('Unknown').str.strip()


# This part of the cods counts total crimes per neighborhood
crime_counts = df[neighborhood_col].value_counts().reset_index()
crime_counts.columns = ['Neighborhood', 'Crime_Count']


# Rank neighborhoods from safest to least safe (lowest to highest crime)
crime_counts_sorted = crime_counts.sort_values(by='Crime_Count', ascending=True).reset_index(drop=True)
crime_counts_sorted['Rank'] = crime_counts_sorted.index + 1  # add rank numbers


# This part of the code prints the top and bottom 10 neighborhoods
print(" Top 10 Safest Neighborhoods (Lowest Crime):")
print(crime_counts_sorted.head(10).to_string(index=False))

print("\n Top 10 Least Safe Neighborhoods (Highest Crime):")
print(crime_counts_sorted.tail(10).sort_values(by='Crime_Count', ascending=False).to_string(index=False))




# This is the part of my code that plots all of hte points onto the bargraph.
plt.figure(figsize=(10, len(crime_counts_sorted) * 0.25))  # auto scale height
plt.barh(crime_counts_sorted['Neighborhood'], crime_counts_sorted['Crime_Count'], color='red')
plt.xlabel('Total Crime Count')
plt.ylabel('Neighborhood')
plt.title('Pittsburgh Neighborhoods Ranked from Safest (Top) to Least Safe (Bottom)')
plt.gca().invert_yaxis()  # safest (lowest crime) appears at top
plt.tight_layout()
plt.show()
# Out:
#  Top 10 Safest Neighborhoods (Lowest Crime):
#            Neighborhood  Crime_Count  Rank
# Mt. Oliver Neighborhood            2     1
#  Troy Hill-Herrs Island            6     2
#         Mt. Oliver Boro           18     3
#       Central Northside           23     4
#           Regent Square           37     5
#               Ridgemont           37     6
#           New Homestead           39     7
#          Swisshelm Park           43     8
#          Chartiers City           46     9
#           East Carnegie           48    10
#
#  Top 10 Least Safe Neighborhoods (Highest Crime):
#              Neighborhood  Crime_Count  Rank
# Central Business District         4440    99
#          South Side Flats         3497    98
#                   Unknown         2489    97
#                   Carrick         2352    96
#            East Allegheny         2217    95
#            Homewood South         2090    94
#            Homewood North         1969    93
# ...
